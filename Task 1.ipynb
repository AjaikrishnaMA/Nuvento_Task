# %%
import xml.etree.ElementTree as ET
import pandas as pd

# %%
tree=ET.parse('C:/Users/USER/Downloads/staging_plugin_indented.xml')

# %%
root=tree.getroot()

# %%
print(ET.tostring(root))
# Out:
# b'<ns0:plugin xmlns:ns0="http://plugin.powerschool.pearson.com" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://plugin.powerschool.pearson.com plugin.xsd" name="Im Plugin-1" version="1.0" description="Im plugin-1">\n   <ns0:oauth />\t\n       <ns0:access_request>\n\t\t\t<ns0:field table="Terms" field="dcid" access="ViewOnly" />\n\t\t\t<ns0:field table="Terms" field="ID" access="ViewOnly" />\n\t\t\t<ns0:field table="Terms" field="Name" access="ViewOnly" />\n\t\t\t<ns0:field table="Terms" field="FirstDay" access="ViewOnly" />\n\t\t\t<ns0:field table="Terms" field="LastDay" access="ViewOnly" />\n\t\t\t<ns0:field table="Terms" field="YearID" access="ViewOnly" />\n\t\t\t<ns0:field table="Terms" field="Abbreviation" access="ViewOnly" />\n\t\t\t<ns0:field table="Terms" field="NoOfDays" access="ViewOnly" />\n\t\t\t<ns0:field table="Terms" field="SchoolID" access="ViewOnly" />\n\t\t\t<ns0:field table="Terms" field="YearlyCreditHrs" access="ViewOnly" />\n\t\t\t
# ...

# %%
lst=[]
for i in tree.findall('table'):
    lst.append(i)
lst
# Out:
# []
